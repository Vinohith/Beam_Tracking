# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/Vinohith/Beam_Tracking.git
# Out:
# Cloning into 'Beam_Tracking'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
# !ls
# %cd Beam_Tracking/VABT/
# !ls
# Out:
# Beam_Tracking  drive  sample_data
# /content/Beam_Tracking/VABT
# build_net.py  data_feed.py  main_beams.py  model_train.py

# %%
# !python main_beams.py
# Out:
# list is ready
# list is ready
# ------------------------------- Commence Training ---------------------------------
# Epoch No. 1--Iteration No. 50-- Mini-batch loss = 4.282425880 and Top-1 accuracy = 0.3150
# Epoch No. 1--Iteration No. 100-- Mini-batch loss = 3.540760279 and Top-1 accuracy = 0.2940
# Validation-- Top-1 accuracy = 0.2966
# Epoch No. 1--Iteration No. 150-- Mini-batch loss = 3.008882284 and Top-1 accuracy = 0.4460
# Epoch No. 1--Iteration No. 200-- Mini-batch loss = 2.654344797 and Top-1 accuracy = 0.5270
# Validation-- Top-1 accuracy = 0.5329
# Epoch No. 1--Iteration No. 250-- Mini-batch loss = 2.386105061 and Top-1 accuracy = 0.6160
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:396: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# Epoch No. 2--Iteration No. 300-- Mini-batch loss = 2.213464022 and Top-1 accuracy = 0.6340
# ...
