# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/Vinohith/Beam_Tracking.git
# Out:
# Cloning into 'Beam_Tracking'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 18 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (18/18), done.

# %%
# !ls
# %cd Beam_Tracking/VABT/
# !ls
# Out:
# Beam_Tracking  drive  sample_data
# /content/Beam_Tracking/VABT
# build_net.py  data_feed.py  main_beams.py  model_train.py

# %%
# !python main_beams.py
# Out:
# list is ready
# list is ready
# ------------------------------- Commence Training ---------------------------------
# Epoch No. 1--Iteration No. 50-- Mini-batch loss = 4.299129009 and Top-1 accuracy = 0.1450
# Epoch No. 1--Iteration No. 100-- Mini-batch loss = 3.559305906 and Top-1 accuracy = 0.1480
# Validation-- Top-1 accuracy = 0.2196
# Epoch No. 1--Iteration No. 150-- Mini-batch loss = 3.156752825 and Top-1 accuracy = 0.3080
# Epoch No. 1--Iteration No. 200-- Mini-batch loss = 2.938092232 and Top-1 accuracy = 0.3190
# Validation-- Top-1 accuracy = 0.3300
# Epoch No. 1--Iteration No. 250-- Mini-batch loss = 2.704128742 and Top-1 accuracy = 0.3400
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:396: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# Epoch No. 2--Iteration No. 300-- Mini-batch loss = 2.500459909 and Top-1 accuracy = 0.3730
# Validation-- Top-1 accuracy = 0.3787
# Epoch No. 2--Iteration No. 350-- Mini-batch loss = 2.423416615 and Top-1 accuracy = 0.3930
# Epoch No. 2--Iteration No. 400-- Mini-batch loss = 2.347972631 and Top-1 accuracy = 0.4040
# Validation-- Top-1 accuracy = 0.4311
# Epoch No. 2--Iteration No. 450-- Mini-batch loss = 2.159719467 and Top-1 accuracy = 0.4540
# Epoch No. 2--Iteration No. 500-- Mini-batch loss = 2.138341665 and Top-1 accuracy = 0.4520
# Validation-- Top-1 accuracy = 0.4493
# Epoch No. 2--Iteration No. 550-- Mini-batch loss = 2.178784370 and Top-1 accuracy = 0.4120
# Epoch No. 3--Iteration No. 600-- Mini-batch loss = 2.043393612 and Top-1 accuracy = 0.4530
# Validation-- Top-1 accuracy = 0.4551
# Epoch No. 3--Iteration No. 650-- Mini-batch loss = 1.994918108 and Top-1 accuracy = 0.4550
# Epoch No. 3--Iteration No. 700-- Mini-batch loss = 2.110560656 and Top-1 accuracy = 0.4310
# Validation-- Top-1 accuracy = 0.4593
# Epoch No. 3--Iteration No. 750-- Mini-batch loss = 1.897482634 and Top-1 accuracy = 0.4740
# Epoch No. 3--Iteration No. 800-- Mini-batch loss = 1.973013401 and Top-1 accuracy = 0.4610
# Validation-- Top-1 accuracy = 0.4602
# Epoch No. 4--Iteration No. 850-- Mini-batch loss = 1.911264300 and Top-1 accuracy = 0.4460
# Epoch No. 4--Iteration No. 900-- Mini-batch loss = 1.815116048 and Top-1 accuracy = 0.4920
# Validation-- Top-1 accuracy = 0.4654
# Epoch No. 4--Iteration No. 950-- Mini-batch loss = 1.872233868 and Top-1 accuracy = 0.4640
# Epoch No. 4--Iteration No. 1000-- Mini-batch loss = 1.892028451 and Top-1 accuracy = 0.4390
# Validation-- Top-1 accuracy = 0.4676
# Epoch No. 4--Iteration No. 1050-- Mini-batch loss = 1.854087591 and Top-1 accuracy = 0.4730
# Epoch No. 4--Iteration No. 1100-- Mini-batch loss = 1.762422562 and Top-1 accuracy = 0.4780
# Validation-- Top-1 accuracy = 0.4679
# Epoch No. 5--Iteration No. 1150-- Mini-batch loss = 1.900746107 and Top-1 accuracy = 0.4260
# Epoch No. 5--Iteration No. 1200-- Mini-batch loss = 1.778887987 and Top-1 accuracy = 0.4940
# Validation-- Top-1 accuracy = 0.4707
# Epoch No. 5--Iteration No. 1250-- Mini-batch loss = 1.710704565 and Top-1 accuracy = 0.4750
# Epoch No. 5--Iteration No. 1300-- Mini-batch loss = 1.805673838 and Top-1 accuracy = 0.4500
# Validation-- Top-1 accuracy = 0.4722
# Epoch No. 5--Iteration No. 1350-- Mini-batch loss = 1.656016946 and Top-1 accuracy = 0.5030
# Epoch No. 5--Iteration No. 1400-- Mini-batch loss = 1.824977517 and Top-1 accuracy = 0.4590
# Validation-- Top-1 accuracy = 0.4730
# Epoch No. 6--Iteration No. 1450-- Mini-batch loss = 1.829295397 and Top-1 accuracy = 0.4560
# Epoch No. 6--Iteration No. 1500-- Mini-batch loss = 1.677822590 and Top-1 accuracy = 0.4890
# Validation-- Top-1 accuracy = 0.4762
# Epoch No. 6--Iteration No. 1550-- Mini-batch loss = 1.753992319 and Top-1 accuracy = 0.4490
# Epoch No. 6--Iteration No. 1600-- Mini-batch loss = 1.762944221 and Top-1 accuracy = 0.4560
# Validation-- Top-1 accuracy = 0.4758
# Epoch No. 6--Iteration No. 1650-- Mini-batch loss = 1.690009952 and Top-1 accuracy = 0.4830
# Epoch No. 7--Iteration No. 1700-- Mini-batch loss = 1.620270491 and Top-1 accuracy = 0.4940
# Validation-- Top-1 accuracy = 0.4770
# Epoch No. 7--Iteration No. 1750-- Mini-batch loss = 1.747912884 and Top-1 accuracy = 0.4550
# Epoch No. 7--Iteration No. 1800-- Mini-batch loss = 1.618988752 and Top-1 accuracy = 0.4850
# Validation-- Top-1 accuracy = 0.4800
# Epoch No. 7--Iteration No. 1850-- Mini-batch loss = 1.666037083 and Top-1 accuracy = 0.4860
# Epoch No. 7--Iteration No. 1900-- Mini-batch loss = 1.641380072 and Top-1 accuracy = 0.4720
# Validation-- Top-1 accuracy = 0.4808
# Epoch No. 7--Iteration No. 1950-- Mini-batch loss = 1.678366065 and Top-1 accuracy = 0.4750
# Epoch No. 8--Iteration No. 2000-- Mini-batch loss = 1.612804532 and Top-1 accuracy = 0.4910
# Validation-- Top-1 accuracy = 0.4822
# Epoch No. 8--Iteration No. 2050-- Mini-batch loss = 1.576868773 and Top-1 accuracy = 0.5010
# Epoch No. 8--Iteration No. 2100-- Mini-batch loss = 1.608955622 and Top-1 accuracy = 0.4850
# Validation-- Top-1 accuracy = 0.4836
# Epoch No. 8--Iteration No. 2150-- Mini-batch loss = 1.723783731 and Top-1 accuracy = 0.4610
# Epoch No. 8--Iteration No. 2200-- Mini-batch loss = 1.607303023 and Top-1 accuracy = 0.4820
# Validation-- Top-1 accuracy = 0.4847
# Epoch No. 8--Iteration No. 2250-- Mini-batch loss = 1.677936316 and Top-1 accuracy = 0.4770
# Epoch No. 9--Iteration No. 2300-- Mini-batch loss = 1.643954635 and Top-1 accuracy = 0.4620
# Validation-- Top-1 accuracy = 0.4876
# Epoch No. 9--Iteration No. 2350-- Mini-batch loss = 1.617774606 and Top-1 accuracy = 0.4770
# Epoch No. 9--Iteration No. 2400-- Mini-batch loss = 1.541310668 and Top-1 accuracy = 0.4990
# Validation-- Top-1 accuracy = 0.4874
# Epoch No. 9--Iteration No. 2450-- Mini-batch loss = 1.631768823 and Top-1 accuracy = 0.4600
# Epoch No. 9--Iteration No. 2500-- Mini-batch loss = 1.600870490 and Top-1 accuracy = 0.4830
# Validation-- Top-1 accuracy = 0.4901
# Epoch No. 10--Iteration No. 2550-- Mini-batch loss = 1.621682167 and Top-1 accuracy = 0.4840
# Epoch No. 10--Iteration No. 2600-- Mini-batch loss = 1.630110025 and Top-1 accuracy = 0.4730
# Validation-- Top-1 accuracy = 0.4878
# Epoch No. 10--Iteration No. 2650-- Mini-batch loss = 1.610465169 and Top-1 accuracy = 0.4800
# Epoch No. 10--Iteration No. 2700-- Mini-batch loss = 1.671309233 and Top-1 accuracy = 0.4650
# Validation-- Top-1 accuracy = 0.4894
# Epoch No. 10--Iteration No. 2750-- Mini-batch loss = 1.661870599 and Top-1 accuracy = 0.4590
# Epoch No. 10--Iteration No. 2800-- Mini-batch loss = 1.638328671 and Top-1 accuracy = 0.4670
# Validation-- Top-1 accuracy = 0.4908
# Epoch No. 11--Iteration No. 2850-- Mini-batch loss = 1.556715488 and Top-1 accuracy = 0.4780
# Epoch No. 11--Iteration No. 2900-- Mini-batch loss = 1.548159122 and Top-1 accuracy = 0.4700
# Validation-- Top-1 accuracy = 0.4911
# Epoch No. 11--Iteration No. 2950-- Mini-batch loss = 1.541676879 and Top-1 accuracy = 0.4860
# Epoch No. 11--Iteration No. 3000-- Mini-batch loss = 1.511313796 and Top-1 accuracy = 0.4910
# Validation-- Top-1 accuracy = 0.4920
# Epoch No. 11--Iteration No. 3050-- Mini-batch loss = 1.624336123 and Top-1 accuracy = 0.4970
# Epoch No. 11--Iteration No. 3100-- Mini-batch loss = 1.592548132 and Top-1 accuracy = 0.4700
# Validation-- Top-1 accuracy = 0.4921
# Epoch No. 12--Iteration No. 3150-- Mini-batch loss = 1.517581105 and Top-1 accuracy = 0.4820
# Epoch No. 12--Iteration No. 3200-- Mini-batch loss = 1.584497571 and Top-1 accuracy = 0.4730
# Validation-- Top-1 accuracy = 0.4920
# Epoch No. 12--Iteration No. 3250-- Mini-batch loss = 1.584085345 and Top-1 accuracy = 0.4810
# Epoch No. 12--Iteration No. 3300-- Mini-batch loss = 1.497591496 and Top-1 accuracy = 0.4880
# Validation-- Top-1 accuracy = 0.4919
# Epoch No. 12--Iteration No. 3350-- Mini-batch loss = 1.547370553 and Top-1 accuracy = 0.4760
# Epoch No. 13--Iteration No. 3400-- Mini-batch loss = 1.611797571 and Top-1 accuracy = 0.4890
# Validation-- Top-1 accuracy = 0.4930
# Epoch No. 13--Iteration No. 3450-- Mini-batch loss = 1.553377628 and Top-1 accuracy = 0.4800
# Epoch No. 13--Iteration No. 3500-- Mini-batch loss = 1.613561034 and Top-1 accuracy = 0.4660
# Validation-- Top-1 accuracy = 0.4943
# Epoch No. 13--Iteration No. 3550-- Mini-batch loss = 1.513421893 and Top-1 accuracy = 0.4930
# Epoch No. 13--Iteration No. 3600-- Mini-batch loss = 1.594968796 and Top-1 accuracy = 0.4910
# Validation-- Top-1 accuracy = 0.4937
# Epoch No. 13--Iteration No. 3650-- Mini-batch loss = 1.465872407 and Top-1 accuracy = 0.4960
# Epoch No. 14--Iteration No. 3700-- Mini-batch loss = 1.510470748 and Top-1 accuracy = 0.4790
# Validation-- Top-1 accuracy = 0.4942
# Epoch No. 14--Iteration No. 3750-- Mini-batch loss = 1.599661827 and Top-1 accuracy = 0.4590
# Epoch No. 14--Iteration No. 3800-- Mini-batch loss = 1.561360955 and Top-1 accuracy = 0.4990
# Validation-- Top-1 accuracy = 0.4964
# Epoch No. 14--Iteration No. 3850-- Mini-batch loss = 1.533735394 and Top-1 accuracy = 0.4780
# Epoch No. 14--Iteration No. 3900-- Mini-batch loss = 1.568426251 and Top-1 accuracy = 0.4770
# Validation-- Top-1 accuracy = 0.4947
# Epoch No. 15--Iteration No. 3950-- Mini-batch loss = 1.537843108 and Top-1 accuracy = 0.4810
# Epoch No. 15--Iteration No. 4000-- Mini-batch loss = 1.609402061 and Top-1 accuracy = 0.4690
# Validation-- Top-1 accuracy = 0.4964
# Epoch No. 15--Iteration No. 4050-- Mini-batch loss = 1.465473652 and Top-1 accuracy = 0.5080
# Epoch No. 15--Iteration No. 4100-- Mini-batch loss = 1.553297400 and Top-1 accuracy = 0.5100
# Validation-- Top-1 accuracy = 0.4965
# Epoch No. 15--Iteration No. 4150-- Mini-batch loss = 1.581642032 and Top-1 accuracy = 0.4690
# Epoch No. 15--Iteration No. 4200-- Mini-batch loss = 1.501048684 and Top-1 accuracy = 0.4840
# Validation-- Top-1 accuracy = 0.4974
# Epoch No. 16--Iteration No. 4250-- Mini-batch loss = 1.476819038 and Top-1 accuracy = 0.4970
# Epoch No. 16--Iteration No. 4300-- Mini-batch loss = 1.531831503 and Top-1 accuracy = 0.4920
# Validation-- Top-1 accuracy = 0.4991
# Epoch No. 16--Iteration No. 4350-- Mini-batch loss = 1.570628524 and Top-1 accuracy = 0.4770
# Epoch No. 16--Iteration No. 4400-- Mini-batch loss = 1.551529765 and Top-1 accuracy = 0.4600
# Validation-- Top-1 accuracy = 0.4971
# Epoch No. 16--Iteration No. 4450-- Mini-batch loss = 1.537871957 and Top-1 accuracy = 0.4740
# Epoch No. 16--Iteration No. 4500-- Mini-batch loss = 1.491245627 and Top-1 accuracy = 0.4870
# Validation-- Top-1 accuracy = 0.4985
# Epoch No. 17--Iteration No. 4550-- Mini-batch loss = 1.567095399 and Top-1 accuracy = 0.4900
# Epoch No. 17--Iteration No. 4600-- Mini-batch loss = 1.532148957 and Top-1 accuracy = 0.4890
# Validation-- Top-1 accuracy = 0.5003
# Epoch No. 17--Iteration No. 4650-- Mini-batch loss = 1.531559348 and Top-1 accuracy = 0.4820
# Epoch No. 17--Iteration No. 4700-- Mini-batch loss = 1.521662712 and Top-1 accuracy = 0.4970
# Validation-- Top-1 accuracy = 0.4991
# Epoch No. 17--Iteration No. 4750-- Mini-batch loss = 1.534640908 and Top-1 accuracy = 0.4720
# Epoch No. 18--Iteration No. 4800-- Mini-batch loss = 1.521734357 and Top-1 accuracy = 0.4820
# Validation-- Top-1 accuracy = 0.5000
# Epoch No. 18--Iteration No. 4850-- Mini-batch loss = 1.460032105 and Top-1 accuracy = 0.5040
# Epoch No. 18--Iteration No. 4900-- Mini-batch loss = 1.588488817 and Top-1 accuracy = 0.4690
# Validation-- Top-1 accuracy = 0.5005
# Epoch No. 18--Iteration No. 4950-- Mini-batch loss = 1.519037604 and Top-1 accuracy = 0.4840
# Epoch No. 18--Iteration No. 5000-- Mini-batch loss = 1.454624176 and Top-1 accuracy = 0.4770
# Validation-- Top-1 accuracy = 0.5014
# Epoch No. 18--Iteration No. 5050-- Mini-batch loss = 1.467093587 and Top-1 accuracy = 0.5090
# Epoch No. 19--Iteration No. 5100-- Mini-batch loss = 1.493343234 and Top-1 accuracy = 0.4910
# Validation-- Top-1 accuracy = 0.5010
# Epoch No. 19--Iteration No. 5150-- Mini-batch loss = 1.476370931 and Top-1 accuracy = 0.4980
# Epoch No. 19--Iteration No. 5200-- Mini-batch loss = 1.505359054 and Top-1 accuracy = 0.4730
# Validation-- Top-1 accuracy = 0.4998
# Epoch No. 19--Iteration No. 5250-- Mini-batch loss = 1.491814256 and Top-1 accuracy = 0.4710
# Epoch No. 19--Iteration No. 5300-- Mini-batch loss = 1.391859174 and Top-1 accuracy = 0.4990
# Validation-- Top-1 accuracy = 0.5024
# Epoch No. 19--Iteration No. 5350-- Mini-batch loss = 1.531422257 and Top-1 accuracy = 0.4790
# Epoch No. 20--Iteration No. 5400-- Mini-batch loss = 1.565608740 and Top-1 accuracy = 0.4710
# Validation-- Top-1 accuracy = 0.5027
# Epoch No. 20--Iteration No. 5450-- Mini-batch loss = 1.474599600 and Top-1 accuracy = 0.4920
# Epoch No. 20--Iteration No. 5500-- Mini-batch loss = 1.365508437 and Top-1 accuracy = 0.5450
# Validation-- Top-1 accuracy = 0.5017
# Epoch No. 20--Iteration No. 5550-- Mini-batch loss = 1.505102873 and Top-1 accuracy = 0.5000
# Epoch No. 20--Iteration No. 5600-- Mini-batch loss = 1.544873238 and Top-1 accuracy = 0.4770
# Validation-- Top-1 accuracy = 0.5030
# Epoch No. 21--Iteration No. 5650-- Mini-batch loss = 1.423687458 and Top-1 accuracy = 0.5240
# Epoch No. 21--Iteration No. 5700-- Mini-batch loss = 1.407788873 and Top-1 accuracy = 0.5190
# Validation-- Top-1 accuracy = 0.5024
# Epoch No. 21--Iteration No. 5750-- Mini-batch loss = 1.516897082 and Top-1 accuracy = 0.4880
# Epoch No. 21--Iteration No. 5800-- Mini-batch loss = 1.384332538 and Top-1 accuracy = 0.5030
# Validation-- Top-1 accuracy = 0.5027
# Epoch No. 21--Iteration No. 5850-- Mini-batch loss = 1.456258178 and Top-1 accuracy = 0.4860
# Epoch No. 21--Iteration No. 5900-- Mini-batch loss = 1.477226377 and Top-1 accuracy = 0.5050
# Validation-- Top-1 accuracy = 0.5021
# Epoch No. 22--Iteration No. 5950-- Mini-batch loss = 1.515333295 and Top-1 accuracy = 0.4940
# Epoch No. 22--Iteration No. 6000-- Mini-batch loss = 1.453623533 and Top-1 accuracy = 0.4970
# Validation-- Top-1 accuracy = 0.5049
# Epoch No. 22--Iteration No. 6050-- Mini-batch loss = 1.483787298 and Top-1 accuracy = 0.4960
# Epoch No. 22--Iteration No. 6100-- Mini-batch loss = 1.452543020 and Top-1 accuracy = 0.4980
# Validation-- Top-1 accuracy = 0.5040
# Epoch No. 22--Iteration No. 6150-- Mini-batch loss = 1.508259773 and Top-1 accuracy = 0.4890
# Epoch No. 22--Iteration No. 6200-- Mini-batch loss = 1.477370620 and Top-1 accuracy = 0.4870
# Validation-- Top-1 accuracy = 0.5059
# Epoch No. 23--Iteration No. 6250-- Mini-batch loss = 1.515810728 and Top-1 accuracy = 0.4770
# Epoch No. 23--Iteration No. 6300-- Mini-batch loss = 1.461971402 and Top-1 accuracy = 0.4920
# Validation-- Top-1 accuracy = 0.5057
# Epoch No. 23--Iteration No. 6350-- Mini-batch loss = 1.450048685 and Top-1 accuracy = 0.5070
# Epoch No. 23--Iteration No. 6400-- Mini-batch loss = 1.561050773 and Top-1 accuracy = 0.4720
# Validation-- Top-1 accuracy = 0.5059
# Epoch No. 23--Iteration No. 6450-- Mini-batch loss = 1.445569515 and Top-1 accuracy = 0.5080
# Epoch No. 24--Iteration No. 6500-- Mini-batch loss = 1.427086592 and Top-1 accuracy = 0.4980
# Validation-- Top-1 accuracy = 0.5054
# Epoch No. 24--Iteration No. 6550-- Mini-batch loss = 1.497092724 and Top-1 accuracy = 0.4910
# Epoch No. 24--Iteration No. 6600-- Mini-batch loss = 1.468089700 and Top-1 accuracy = 0.4820
# Validation-- Top-1 accuracy = 0.5057
# Epoch No. 24--Iteration No. 6650-- Mini-batch loss = 1.513549328 and Top-1 accuracy = 0.4970
# Epoch No. 24--Iteration No. 6700-- Mini-batch loss = 1.516508818 and Top-1 accuracy = 0.4840
# Validation-- Top-1 accuracy = 0.5064
# Epoch No. 24--Iteration No. 6750-- Mini-batch loss = 1.445444942 and Top-1 accuracy = 0.4860
# Epoch No. 25--Iteration No. 6800-- Mini-batch loss = 1.353521585 and Top-1 accuracy = 0.5220
# Validation-- Top-1 accuracy = 0.5058
# Epoch No. 25--Iteration No. 6850-- Mini-batch loss = 1.438587189 and Top-1 accuracy = 0.5150
# Epoch No. 25--Iteration No. 6900-- Mini-batch loss = 1.492011547 and Top-1 accuracy = 0.4930
# Validation-- Top-1 accuracy = 0.5062
# Epoch No. 25--Iteration No. 6950-- Mini-batch loss = 1.454952955 and Top-1 accuracy = 0.4890
# Epoch No. 25--Iteration No. 7000-- Mini-batch loss = 1.530675411 and Top-1 accuracy = 0.4640
# Validation-- Top-1 accuracy = 0.5058
# Epoch No. 25--Iteration No. 7050-- Mini-batch loss = 1.394264579 and Top-1 accuracy = 0.4700
# Epoch No. 26--Iteration No. 7100-- Mini-batch loss = 1.445460558 and Top-1 accuracy = 0.4990
# Validation-- Top-1 accuracy = 0.5065
# Epoch No. 26--Iteration No. 7150-- Mini-batch loss = 1.470261097 and Top-1 accuracy = 0.4940
# Epoch No. 26--Iteration No. 7200-- Mini-batch loss = 1.402706385 and Top-1 accuracy = 0.5000
# Validation-- Top-1 accuracy = 0.5067
# Epoch No. 26--Iteration No. 7250-- Mini-batch loss = 1.488052607 and Top-1 accuracy = 0.5090
# Epoch No. 26--Iteration No. 7300-- Mini-batch loss = 1.446902871 and Top-1 accuracy = 0.5020
# Validation-- Top-1 accuracy = 0.5062
# Epoch No. 27--Iteration No. 7350-- Mini-batch loss = 1.385100245 and Top-1 accuracy = 0.5070
# Epoch No. 27--Iteration No. 7400-- Mini-batch loss = 1.448275447 and Top-1 accuracy = 0.4880
# Validation-- Top-1 accuracy = 0.5067
# Epoch No. 27--Iteration No. 7450-- Mini-batch loss = 1.526082516 and Top-1 accuracy = 0.4760
# Epoch No. 27--Iteration No. 7500-- Mini-batch loss = 1.352883339 and Top-1 accuracy = 0.5180
# Validation-- Top-1 accuracy = 0.5084
# Epoch No. 27--Iteration No. 7550-- Mini-batch loss = 1.392130971 and Top-1 accuracy = 0.5140
# Epoch No. 27--Iteration No. 7600-- Mini-batch loss = 1.493404269 and Top-1 accuracy = 0.4740
# Validation-- Top-1 accuracy = 0.5078
# Epoch No. 28--Iteration No. 7650-- Mini-batch loss = 1.455320477 and Top-1 accuracy = 0.5030
# Epoch No. 28--Iteration No. 7700-- Mini-batch loss = 1.460278273 and Top-1 accuracy = 0.5000
# Validation-- Top-1 accuracy = 0.5078
# Epoch No. 28--Iteration No. 7750-- Mini-batch loss = 1.554576278 and Top-1 accuracy = 0.4690
# Epoch No. 28--Iteration No. 7800-- Mini-batch loss = 1.426091909 and Top-1 accuracy = 0.5080
# Validation-- Top-1 accuracy = 0.5083
# Epoch No. 28--Iteration No. 7850-- Mini-batch loss = 1.509185433 and Top-1 accuracy = 0.4870
# Epoch No. 29--Iteration No. 7900-- Mini-batch loss = 1.437444448 and Top-1 accuracy = 0.4910
# Validation-- Top-1 accuracy = 0.5084
# Epoch No. 29--Iteration No. 7950-- Mini-batch loss = 1.378422141 and Top-1 accuracy = 0.5260
# Epoch No. 29--Iteration No. 8000-- Mini-batch loss = 1.457977653 and Top-1 accuracy = 0.5010
# Validation-- Top-1 accuracy = 0.5076
# Epoch No. 29--Iteration No. 8050-- Mini-batch loss = 1.468369246 and Top-1 accuracy = 0.4760
# Epoch No. 29--Iteration No. 8100-- Mini-batch loss = 1.466324925 and Top-1 accuracy = 0.5060
# Validation-- Top-1 accuracy = 0.5085
# Epoch No. 29--Iteration No. 8150-- Mini-batch loss = 1.418616176 and Top-1 accuracy = 0.5100
# Epoch No. 30--Iteration No. 8200-- Mini-batch loss = 1.523462415 and Top-1 accuracy = 0.4670
# Validation-- Top-1 accuracy = 0.5081
# Epoch No. 30--Iteration No. 8250-- Mini-batch loss = 1.436209917 and Top-1 accuracy = 0.5170
# Epoch No. 30--Iteration No. 8300-- Mini-batch loss = 1.385690808 and Top-1 accuracy = 0.5090
# Validation-- Top-1 accuracy = 0.5079
# Epoch No. 30--Iteration No. 8350-- Mini-batch loss = 1.480781794 and Top-1 accuracy = 0.4750
# Epoch No. 30--Iteration No. 8400-- Mini-batch loss = 1.352998137 and Top-1 accuracy = 0.5170
# Validation-- Top-1 accuracy = 0.5086
# Epoch No. 30--Iteration No. 8450-- Mini-batch loss = 1.494167924 and Top-1 accuracy = 0.4910
# Epoch No. 31--Iteration No. 8500-- Mini-batch loss = 1.509518504 and Top-1 accuracy = 0.4910
# Validation-- Top-1 accuracy = 0.5090
# Epoch No. 31--Iteration No. 8550-- Mini-batch loss = 1.393636107 and Top-1 accuracy = 0.5230
# Epoch No. 31--Iteration No. 8600-- Mini-batch loss = 1.459678054 and Top-1 accuracy = 0.4770
# Validation-- Top-1 accuracy = 0.5089
# Epoch No. 31--Iteration No. 8650-- Mini-batch loss = 1.464897633 and Top-1 accuracy = 0.4730
# Epoch No. 31--Iteration No. 8700-- Mini-batch loss = 1.421806455 and Top-1 accuracy = 0.5070
# Validation-- Top-1 accuracy = 0.5077
# Epoch No. 32--Iteration No. 8750-- Mini-batch loss = 1.384139299 and Top-1 accuracy = 0.5080
# Epoch No. 32--Iteration No. 8800-- Mini-batch loss = 1.491331220 and Top-1 accuracy = 0.4810
# Validation-- Top-1 accuracy = 0.5075
# Epoch No. 32--Iteration No. 8850-- Mini-batch loss = 1.384500623 and Top-1 accuracy = 0.5000
# Epoch No. 32--Iteration No. 8900-- Mini-batch loss = 1.409622192 and Top-1 accuracy = 0.5120
# Validation-- Top-1 accuracy = 0.5069
# Epoch No. 32--Iteration No. 8950-- Mini-batch loss = 1.397903919 and Top-1 accuracy = 0.5190
# Epoch No. 32--Iteration No. 9000-- Mini-batch loss = 1.415531874 and Top-1 accuracy = 0.4960
# Validation-- Top-1 accuracy = 0.5080
# Epoch No. 33--Iteration No. 9050-- Mini-batch loss = 1.375119925 and Top-1 accuracy = 0.5200
# Epoch No. 33--Iteration No. 9100-- Mini-batch loss = 1.374717832 and Top-1 accuracy = 0.5330
# Validation-- Top-1 accuracy = 0.5082
# Epoch No. 33--Iteration No. 9150-- Mini-batch loss = 1.432642698 and Top-1 accuracy = 0.5010
# Epoch No. 33--Iteration No. 9200-- Mini-batch loss = 1.519453883 and Top-1 accuracy = 0.4720
# Validation-- Top-1 accuracy = 0.5079
# Epoch No. 33--Iteration No. 9250-- Mini-batch loss = 1.396420956 and Top-1 accuracy = 0.5070
# Epoch No. 33--Iteration No. 9300-- Mini-batch loss = 1.488042593 and Top-1 accuracy = 0.4960
# Validation-- Top-1 accuracy = 0.5091
# Epoch No. 34--Iteration No. 9350-- Mini-batch loss = 1.440231800 and Top-1 accuracy = 0.4840
# Epoch No. 34--Iteration No. 9400-- Mini-batch loss = 1.449748874 and Top-1 accuracy = 0.5130
# Validation-- Top-1 accuracy = 0.5085
# Epoch No. 34--Iteration No. 9450-- Mini-batch loss = 1.373096347 and Top-1 accuracy = 0.5260
# Epoch No. 34--Iteration No. 9500-- Mini-batch loss = 1.433666706 and Top-1 accuracy = 0.4870
# Validation-- Top-1 accuracy = 0.5079
# Epoch No. 34--Iteration No. 9550-- Mini-batch loss = 1.440798640 and Top-1 accuracy = 0.5080
# Epoch No. 35--Iteration No. 9600-- Mini-batch loss = 1.473539114 and Top-1 accuracy = 0.5050
# Validation-- Top-1 accuracy = 0.5094
# Epoch No. 35--Iteration No. 9650-- Mini-batch loss = 1.476530433 and Top-1 accuracy = 0.4960
# Epoch No. 35--Iteration No. 9700-- Mini-batch loss = 1.420425892 and Top-1 accuracy = 0.4910
# Validation-- Top-1 accuracy = 0.5085
# Epoch No. 35--Iteration No. 9750-- Mini-batch loss = 1.469570756 and Top-1 accuracy = 0.4870
# Epoch No. 35--Iteration No. 9800-- Mini-batch loss = 1.466024399 and Top-1 accuracy = 0.4770
# Validation-- Top-1 accuracy = 0.5100
# Epoch No. 35--Iteration No. 9850-- Mini-batch loss = 1.467859864 and Top-1 accuracy = 0.4900
# Epoch No. 36--Iteration No. 9900-- Mini-batch loss = 1.391159296 and Top-1 accuracy = 0.4960
# Validation-- Top-1 accuracy = 0.5087
# Epoch No. 36--Iteration No. 9950-- Mini-batch loss = 1.385102510 and Top-1 accuracy = 0.4830
# Epoch No. 36--Iteration No. 10000-- Mini-batch loss = 1.361631632 and Top-1 accuracy = 0.5180
# Validation-- Top-1 accuracy = 0.5091
# Epoch No. 36--Iteration No. 10050-- Mini-batch loss = 1.364119887 and Top-1 accuracy = 0.5150
# Epoch No. 36--Iteration No. 10100-- Mini-batch loss = 1.470802069 and Top-1 accuracy = 0.5060
# Validation-- Top-1 accuracy = 0.5112
# Epoch No. 36--Iteration No. 10150-- Mini-batch loss = 1.425539494 and Top-1 accuracy = 0.4880
# Epoch No. 37--Iteration No. 10200-- Mini-batch loss = 1.377190590 and Top-1 accuracy = 0.4980
# Validation-- Top-1 accuracy = 0.5091
# Epoch No. 37--Iteration No. 10250-- Mini-batch loss = 1.448811054 and Top-1 accuracy = 0.4750
# Epoch No. 37--Iteration No. 10300-- Mini-batch loss = 1.430080771 and Top-1 accuracy = 0.5020
# Validation-- Top-1 accuracy = 0.5096
# Epoch No. 37--Iteration No. 10350-- Mini-batch loss = 1.351625323 and Top-1 accuracy = 0.5050
# Epoch No. 37--Iteration No. 10400-- Mini-batch loss = 1.398679972 and Top-1 accuracy = 0.4990
# Validation-- Top-1 accuracy = 0.5086
# Epoch No. 38--Iteration No. 10450-- Mini-batch loss = 1.495577693 and Top-1 accuracy = 0.4960
# Epoch No. 38--Iteration No. 10500-- Mini-batch loss = 1.419637203 and Top-1 accuracy = 0.5010
# Validation-- Top-1 accuracy = 0.5106
# Epoch No. 38--Iteration No. 10550-- Mini-batch loss = 1.467326641 and Top-1 accuracy = 0.4880
# Epoch No. 38--Iteration No. 10600-- Mini-batch loss = 1.401304364 and Top-1 accuracy = 0.5030
# Validation-- Top-1 accuracy = 0.5097
# Epoch No. 38--Iteration No. 10650-- Mini-batch loss = 1.457738280 and Top-1 accuracy = 0.4990
# Epoch No. 38--Iteration No. 10700-- Mini-batch loss = 1.343751669 and Top-1 accuracy = 0.5090
# Validation-- Top-1 accuracy = 0.5099
# Epoch No. 39--Iteration No. 10750-- Mini-batch loss = 1.372239232 and Top-1 accuracy = 0.5050
# Epoch No. 39--Iteration No. 10800-- Mini-batch loss = 1.469163895 and Top-1 accuracy = 0.4650
# Validation-- Top-1 accuracy = 0.5112
# Epoch No. 39--Iteration No. 10850-- Mini-batch loss = 1.459672332 and Top-1 accuracy = 0.5040
# Epoch No. 39--Iteration No. 10900-- Mini-batch loss = 1.414430499 and Top-1 accuracy = 0.5010
# Validation-- Top-1 accuracy = 0.5109
# Epoch No. 39--Iteration No. 10950-- Mini-batch loss = 1.433503151 and Top-1 accuracy = 0.4990
# Epoch No. 40--Iteration No. 11000-- Mini-batch loss = 1.376952291 and Top-1 accuracy = 0.5010
# Validation-- Top-1 accuracy = 0.5106
# Epoch No. 40--Iteration No. 11050-- Mini-batch loss = 1.481405616 and Top-1 accuracy = 0.4850
# Epoch No. 40--Iteration No. 11100-- Mini-batch loss = 1.354506850 and Top-1 accuracy = 0.5280
# Validation-- Top-1 accuracy = 0.5115
# Epoch No. 40--Iteration No. 11150-- Mini-batch loss = 1.434854507 and Top-1 accuracy = 0.5150
# Epoch No. 40--Iteration No. 11200-- Mini-batch loss = 1.475095868 and Top-1 accuracy = 0.4910
# Validation-- Top-1 accuracy = 0.5116
# Epoch No. 40--Iteration No. 11250-- Mini-batch loss = 1.388490915 and Top-1 accuracy = 0.5090
# Epoch No. 41--Iteration No. 11300-- Mini-batch loss = 1.388118148 and Top-1 accuracy = 0.4960
# Validation-- Top-1 accuracy = 0.5114
# Epoch No. 41--Iteration No. 11350-- Mini-batch loss = 1.384950638 and Top-1 accuracy = 0.4890
# Epoch No. 41--Iteration No. 11400-- Mini-batch loss = 1.455109358 and Top-1 accuracy = 0.4900
# Validation-- Top-1 accuracy = 0.5101
# Epoch No. 41--Iteration No. 11450-- Mini-batch loss = 1.437200069 and Top-1 accuracy = 0.4730
# Epoch No. 41--Iteration No. 11500-- Mini-batch loss = 1.421645880 and Top-1 accuracy = 0.4990
# Validation-- Top-1 accuracy = 0.5131
# Epoch No. 41--Iteration No. 11550-- Mini-batch loss = 1.361320257 and Top-1 accuracy = 0.5120
# Epoch No. 42--Iteration No. 11600-- Mini-batch loss = 1.428323388 and Top-1 accuracy = 0.5020
# Validation-- Top-1 accuracy = 0.5110
# Epoch No. 42--Iteration No. 11650-- Mini-batch loss = 1.409752250 and Top-1 accuracy = 0.4960
# Epoch No. 42--Iteration No. 11700-- Mini-batch loss = 1.431859970 and Top-1 accuracy = 0.4920
# Validation-- Top-1 accuracy = 0.5115
# Epoch No. 42--Iteration No. 11750-- Mini-batch loss = 1.425482392 and Top-1 accuracy = 0.4940
# Epoch No. 42--Iteration No. 11800-- Mini-batch loss = 1.443242669 and Top-1 accuracy = 0.4800
# Validation-- Top-1 accuracy = 0.5109
# Epoch No. 43--Iteration No. 11850-- Mini-batch loss = 1.397473454 and Top-1 accuracy = 0.5090
# Epoch No. 43--Iteration No. 11900-- Mini-batch loss = 1.374004245 and Top-1 accuracy = 0.5030
# Validation-- Top-1 accuracy = 0.5114
# Epoch No. 43--Iteration No. 11950-- Mini-batch loss = 1.483921528 and Top-1 accuracy = 0.4830
# Epoch No. 43--Iteration No. 12000-- Mini-batch loss = 1.407190084 and Top-1 accuracy = 0.5000
# Validation-- Top-1 accuracy = 0.5125
# Epoch No. 43--Iteration No. 12050-- Mini-batch loss = 1.358986616 and Top-1 accuracy = 0.4970
# Epoch No. 43--Iteration No. 12100-- Mini-batch loss = 1.389117479 and Top-1 accuracy = 0.5170
# Validation-- Top-1 accuracy = 0.5119
# Epoch No. 44--Iteration No. 12150-- Mini-batch loss = 1.396592975 and Top-1 accuracy = 0.4920
# Epoch No. 44--Iteration No. 12200-- Mini-batch loss = 1.399184704 and Top-1 accuracy = 0.5070
# Validation-- Top-1 accuracy = 0.5126
# Epoch No. 44--Iteration No. 12250-- Mini-batch loss = 1.410954237 and Top-1 accuracy = 0.5020
# Epoch No. 44--Iteration No. 12300-- Mini-batch loss = 1.400918126 and Top-1 accuracy = 0.4880
# Validation-- Top-1 accuracy = 0.5110
# Epoch No. 44--Iteration No. 12350-- Mini-batch loss = 1.308271050 and Top-1 accuracy = 0.5100
# Epoch No. 44--Iteration No. 12400-- Mini-batch loss = 1.428955436 and Top-1 accuracy = 0.4890
# Validation-- Top-1 accuracy = 0.5120
# Epoch No. 45--Iteration No. 12450-- Mini-batch loss = 1.458779573 and Top-1 accuracy = 0.4740
# Epoch No. 45--Iteration No. 12500-- Mini-batch loss = 1.366265297 and Top-1 accuracy = 0.5020
# Validation-- Top-1 accuracy = 0.5123
# Epoch No. 45--Iteration No. 12550-- Mini-batch loss = 1.280118942 and Top-1 accuracy = 0.5530
# Epoch No. 45--Iteration No. 12600-- Mini-batch loss = 1.427021980 and Top-1 accuracy = 0.5010
# Validation-- Top-1 accuracy = 0.5114
# Epoch No. 45--Iteration No. 12650-- Mini-batch loss = 1.459179401 and Top-1 accuracy = 0.4840
# Epoch No. 46--Iteration No. 12700-- Mini-batch loss = 1.362722039 and Top-1 accuracy = 0.5320
# Validation-- Top-1 accuracy = 0.5119
# Epoch No. 46--Iteration No. 12750-- Mini-batch loss = 1.336456180 and Top-1 accuracy = 0.5210
# Epoch No. 46--Iteration No. 12800-- Mini-batch loss = 1.436617851 and Top-1 accuracy = 0.4890
# Validation-- Top-1 accuracy = 0.5113
# Epoch No. 46--Iteration No. 12850-- Mini-batch loss = 1.330351472 and Top-1 accuracy = 0.5250
# Epoch No. 46--Iteration No. 12900-- Mini-batch loss = 1.369311213 and Top-1 accuracy = 0.4910
# Validation-- Top-1 accuracy = 0.5118
# Epoch No. 46--Iteration No. 12950-- Mini-batch loss = 1.405016065 and Top-1 accuracy = 0.5160
# Epoch No. 47--Iteration No. 13000-- Mini-batch loss = 1.440244794 and Top-1 accuracy = 0.4910
# Validation-- Top-1 accuracy = 0.5116
# Epoch No. 47--Iteration No. 13050-- Mini-batch loss = 1.379811645 and Top-1 accuracy = 0.5030
# Epoch No. 47--Iteration No. 13100-- Mini-batch loss = 1.394348145 and Top-1 accuracy = 0.5020
# Validation-- Top-1 accuracy = 0.5112
# Epoch No. 47--Iteration No. 13150-- Mini-batch loss = 1.371657372 and Top-1 accuracy = 0.5070
# Epoch No. 47--Iteration No. 13200-- Mini-batch loss = 1.420477986 and Top-1 accuracy = 0.4980
# Validation-- Top-1 accuracy = 0.5127
# Epoch No. 47--Iteration No. 13250-- Mini-batch loss = 1.392891288 and Top-1 accuracy = 0.5030
# Epoch No. 48--Iteration No. 13300-- Mini-batch loss = 1.442441225 and Top-1 accuracy = 0.4880
# Validation-- Top-1 accuracy = 0.5116
# Epoch No. 48--Iteration No. 13350-- Mini-batch loss = 1.378083825 and Top-1 accuracy = 0.5050
# Epoch No. 48--Iteration No. 13400-- Mini-batch loss = 1.397763848 and Top-1 accuracy = 0.5160
# Validation-- Top-1 accuracy = 0.5123
# Epoch No. 48--Iteration No. 13450-- Mini-batch loss = 1.488108039 and Top-1 accuracy = 0.4850
# Epoch No. 48--Iteration No. 13500-- Mini-batch loss = 1.359713674 and Top-1 accuracy = 0.5170
# Validation-- Top-1 accuracy = 0.5115
# Epoch No. 49--Iteration No. 13550-- Mini-batch loss = 1.344580054 and Top-1 accuracy = 0.5070
# Epoch No. 49--Iteration No. 13600-- Mini-batch loss = 1.436708689 and Top-1 accuracy = 0.5070
# Validation-- Top-1 accuracy = 0.5117
# Epoch No. 49--Iteration No. 13650-- Mini-batch loss = 1.406900525 and Top-1 accuracy = 0.4850
# Epoch No. 49--Iteration No. 13700-- Mini-batch loss = 1.439500690 and Top-1 accuracy = 0.5000
# Validation-- Top-1 accuracy = 0.5120
# Epoch No. 49--Iteration No. 13750-- Mini-batch loss = 1.449035525 and Top-1 accuracy = 0.4900
# Epoch No. 49--Iteration No. 13800-- Mini-batch loss = 1.396648765 and Top-1 accuracy = 0.5010
# Validation-- Top-1 accuracy = 0.5116
# Epoch No. 50--Iteration No. 13850-- Mini-batch loss = 1.284449697 and Top-1 accuracy = 0.5350
# Epoch No. 50--Iteration No. 13900-- Mini-batch loss = 1.353492022 and Top-1 accuracy = 0.5220
# Validation-- Top-1 accuracy = 0.5126
# Epoch No. 50--Iteration No. 13950-- Mini-batch loss = 1.434527040 and Top-1 accuracy = 0.5100
# Epoch No. 50--Iteration No. 14000-- Mini-batch loss = 1.376483202 and Top-1 accuracy = 0.4940
# Validation-- Top-1 accuracy = 0.5112
# Epoch No. 50--Iteration No. 14050-- Mini-batch loss = 1.452401638 and Top-1 accuracy = 0.4640
# Epoch No. 50--Iteration No. 14100-- Mini-batch loss = 1.261509180 and Top-1 accuracy = 0.4700
# Validation-- Top-1 accuracy = 0.5123
# Training lasted 26546668.955 minutes
# ------------------------ Training Done ------------------------
# <Figure size 640x480 with 1 Axes>
