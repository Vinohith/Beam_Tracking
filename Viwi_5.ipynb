# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/Vinohith/Beam_Tracking.git
# Out:
# Cloning into 'Beam_Tracking'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 18 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (18/18), done.

# %%
# !ls
# %cd Beam_Tracking/VABT/
# !ls
# Out:
# Beam_Tracking  drive  sample_data
# /content/Beam_Tracking/VABT
# build_net.py  data_feed.py  main_beams.py  model_train.py

# %%
# !python main_beams.py
# Out:
# list is ready
# list is ready
# ------------------------------- Commence Training ---------------------------------
# Epoch No. 1--Iteration No. 50-- Mini-batch loss = 4.373206615 and Top-1 accuracy = 0.0920
# Epoch No. 1--Iteration No. 100-- Mini-batch loss = 3.614416838 and Top-1 accuracy = 0.2320
# Validation-- Top-1 accuracy = 0.2353
# Epoch No. 1--Iteration No. 150-- Mini-batch loss = 3.328003407 and Top-1 accuracy = 0.2430
# Epoch No. 1--Iteration No. 200-- Mini-batch loss = 3.083574533 and Top-1 accuracy = 0.2520
# Validation-- Top-1 accuracy = 0.2536
# Epoch No. 1--Iteration No. 250-- Mini-batch loss = 2.932174206 and Top-1 accuracy = 0.2440
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:396: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# Epoch No. 2--Iteration No. 300-- Mini-batch loss = 2.741676331 and Top-1 accuracy = 0.2620
# Validation-- Top-1 accuracy = 0.3096
# Epoch No. 2--Iteration No. 350-- Mini-batch loss = 2.625470400 and Top-1 accuracy = 0.2900
# Epoch No. 2--Iteration No. 400-- Mini-batch loss = 2.565564156 and Top-1 accuracy = 0.2990
# Validation-- Top-1 accuracy = 0.3164
# Epoch No. 2--Iteration No. 450-- Mini-batch loss = 2.455507994 and Top-1 accuracy = 0.3070
# Epoch No. 2--Iteration No. 500-- Mini-batch loss = 2.391330004 and Top-1 accuracy = 0.3120
# Validation-- Top-1 accuracy = 0.3298
# Epoch No. 2--Iteration No. 550-- Mini-batch loss = 2.252835989 and Top-1 accuracy = 0.3430
# Epoch No. 3--Iteration No. 600-- Mini-batch loss = 2.222946405 and Top-1 accuracy = 0.3300
# Validation-- Top-1 accuracy = 0.3339
# Epoch No. 3--Iteration No. 650-- Mini-batch loss = 2.224340677 and Top-1 accuracy = 0.3240
# Epoch No. 3--Iteration No. 700-- Mini-batch loss = 2.180604696 and Top-1 accuracy = 0.3230
# Validation-- Top-1 accuracy = 0.3348
# Epoch No. 3--Iteration No. 750-- Mini-batch loss = 2.194084883 and Top-1 accuracy = 0.3480
# Epoch No. 3--Iteration No. 800-- Mini-batch loss = 2.152439833 and Top-1 accuracy = 0.3300
# Validation-- Top-1 accuracy = 0.3348
# Epoch No. 4--Iteration No. 850-- Mini-batch loss = 2.111435413 and Top-1 accuracy = 0.3200
# Epoch No. 4--Iteration No. 900-- Mini-batch loss = 2.223419666 and Top-1 accuracy = 0.3200
# Validation-- Top-1 accuracy = 0.3349
# Epoch No. 4--Iteration No. 950-- Mini-batch loss = 2.118041277 and Top-1 accuracy = 0.3360
# Epoch No. 4--Iteration No. 1000-- Mini-batch loss = 2.073627234 and Top-1 accuracy = 0.3260
# Validation-- Top-1 accuracy = 0.3354
# Epoch No. 4--Iteration No. 1050-- Mini-batch loss = 2.191477060 and Top-1 accuracy = 0.3130
# Epoch No. 4--Iteration No. 1100-- Mini-batch loss = 2.103500843 and Top-1 accuracy = 0.3170
# Validation-- Top-1 accuracy = 0.3347
# Epoch No. 5--Iteration No. 1150-- Mini-batch loss = 2.026332378 and Top-1 accuracy = 0.3360
# Epoch No. 5--Iteration No. 1200-- Mini-batch loss = 2.137598991 and Top-1 accuracy = 0.3170
# Validation-- Top-1 accuracy = 0.3373
# Epoch No. 5--Iteration No. 1250-- Mini-batch loss = 2.036847830 and Top-1 accuracy = 0.3400
# Epoch No. 5--Iteration No. 1300-- Mini-batch loss = 2.016153812 and Top-1 accuracy = 0.3510
# Validation-- Top-1 accuracy = 0.3361
# Epoch No. 5--Iteration No. 1350-- Mini-batch loss = 2.007769823 and Top-1 accuracy = 0.3270
# Epoch No. 5--Iteration No. 1400-- Mini-batch loss = 2.052775860 and Top-1 accuracy = 0.3170
# Validation-- Top-1 accuracy = 0.3381
# Epoch No. 6--Iteration No. 1450-- Mini-batch loss = 2.073085546 and Top-1 accuracy = 0.3110
# Epoch No. 6--Iteration No. 1500-- Mini-batch loss = 2.026918650 and Top-1 accuracy = 0.3430
# Validation-- Top-1 accuracy = 0.3400
# Epoch No. 6--Iteration No. 1550-- Mini-batch loss = 2.039237499 and Top-1 accuracy = 0.3120
# Epoch No. 6--Iteration No. 1600-- Mini-batch loss = 1.993257046 and Top-1 accuracy = 0.3420
# Validation-- Top-1 accuracy = 0.3424
# Epoch No. 6--Iteration No. 1650-- Mini-batch loss = 2.015326023 and Top-1 accuracy = 0.3260
# Epoch No. 7--Iteration No. 1700-- Mini-batch loss = 1.922083259 and Top-1 accuracy = 0.3530
# Validation-- Top-1 accuracy = 0.3436
# Epoch No. 7--Iteration No. 1750-- Mini-batch loss = 1.992247462 and Top-1 accuracy = 0.3160
# Epoch No. 7--Iteration No. 1800-- Mini-batch loss = 1.963948250 and Top-1 accuracy = 0.3550
# Validation-- Top-1 accuracy = 0.3425
# Epoch No. 7--Iteration No. 1850-- Mini-batch loss = 1.931654334 and Top-1 accuracy = 0.3440
# Epoch No. 7--Iteration No. 1900-- Mini-batch loss = 1.993819714 and Top-1 accuracy = 0.3320
# Validation-- Top-1 accuracy = 0.3449
# Epoch No. 7--Iteration No. 1950-- Mini-batch loss = 1.978276134 and Top-1 accuracy = 0.3290
# Epoch No. 8--Iteration No. 2000-- Mini-batch loss = 1.903255224 and Top-1 accuracy = 0.3710
# Validation-- Top-1 accuracy = 0.3441
# Epoch No. 8--Iteration No. 2050-- Mini-batch loss = 1.906596661 and Top-1 accuracy = 0.3320
# Epoch No. 8--Iteration No. 2100-- Mini-batch loss = 1.903684378 and Top-1 accuracy = 0.3550
# Validation-- Top-1 accuracy = 0.3441
# Epoch No. 8--Iteration No. 2150-- Mini-batch loss = 1.830955029 and Top-1 accuracy = 0.3410
# Epoch No. 8--Iteration No. 2200-- Mini-batch loss = 1.901218534 and Top-1 accuracy = 0.3580
# Validation-- Top-1 accuracy = 0.3456
# Epoch No. 8--Iteration No. 2250-- Mini-batch loss = 1.850276709 and Top-1 accuracy = 0.3650
# Epoch No. 9--Iteration No. 2300-- Mini-batch loss = 1.919275761 and Top-1 accuracy = 0.3380
# Validation-- Top-1 accuracy = 0.3454
# Epoch No. 9--Iteration No. 2350-- Mini-batch loss = 1.891147017 and Top-1 accuracy = 0.3330
# Epoch No. 9--Iteration No. 2400-- Mini-batch loss = 1.909721732 and Top-1 accuracy = 0.3370
# Validation-- Top-1 accuracy = 0.3446
# Epoch No. 9--Iteration No. 2450-- Mini-batch loss = 1.907206416 and Top-1 accuracy = 0.3250
# Epoch No. 9--Iteration No. 2500-- Mini-batch loss = 1.964952111 and Top-1 accuracy = 0.3430
# Validation-- Top-1 accuracy = 0.3451
# Epoch No. 10--Iteration No. 2550-- Mini-batch loss = 1.928237915 and Top-1 accuracy = 0.3280
# Epoch No. 10--Iteration No. 2600-- Mini-batch loss = 1.827559233 and Top-1 accuracy = 0.3540
# Validation-- Top-1 accuracy = 0.3457
# Epoch No. 10--Iteration No. 2650-- Mini-batch loss = 1.895270944 and Top-1 accuracy = 0.3290
# Epoch No. 10--Iteration No. 2700-- Mini-batch loss = 1.982240796 and Top-1 accuracy = 0.3200
# Validation-- Top-1 accuracy = 0.3453
# Epoch No. 10--Iteration No. 2750-- Mini-batch loss = 1.864116430 and Top-1 accuracy = 0.3660
# Epoch No. 10--Iteration No. 2800-- Mini-batch loss = 1.821891546 and Top-1 accuracy = 0.3380
# Validation-- Top-1 accuracy = 0.3455
# Epoch No. 11--Iteration No. 2850-- Mini-batch loss = 1.845230103 and Top-1 accuracy = 0.3460
# Epoch No. 11--Iteration No. 2900-- Mini-batch loss = 1.943843365 and Top-1 accuracy = 0.3460
# Validation-- Top-1 accuracy = 0.3462
# Epoch No. 11--Iteration No. 2950-- Mini-batch loss = 1.785240769 and Top-1 accuracy = 0.3530
# Epoch No. 11--Iteration No. 3000-- Mini-batch loss = 1.783808827 and Top-1 accuracy = 0.3660
# Validation-- Top-1 accuracy = 0.3450
# Epoch No. 11--Iteration No. 3050-- Mini-batch loss = 1.906124592 and Top-1 accuracy = 0.3260
# Epoch No. 11--Iteration No. 3100-- Mini-batch loss = 1.946121931 and Top-1 accuracy = 0.3270
# Validation-- Top-1 accuracy = 0.3493
# Epoch No. 12--Iteration No. 3150-- Mini-batch loss = 1.883376360 and Top-1 accuracy = 0.3400
# Epoch No. 12--Iteration No. 3200-- Mini-batch loss = 1.918437839 and Top-1 accuracy = 0.3260
# Validation-- Top-1 accuracy = 0.3443
# Epoch No. 12--Iteration No. 3250-- Mini-batch loss = 1.851819873 and Top-1 accuracy = 0.3380
# Epoch No. 12--Iteration No. 3300-- Mini-batch loss = 1.917471290 and Top-1 accuracy = 0.3310
# Validation-- Top-1 accuracy = 0.3482
# Epoch No. 12--Iteration No. 3350-- Mini-batch loss = 1.925212860 and Top-1 accuracy = 0.3080
# Epoch No. 13--Iteration No. 3400-- Mini-batch loss = 1.882512331 and Top-1 accuracy = 0.3440
# Validation-- Top-1 accuracy = 0.3480
# Epoch No. 13--Iteration No. 3450-- Mini-batch loss = 1.852012515 and Top-1 accuracy = 0.3470
# Epoch No. 13--Iteration No. 3500-- Mini-batch loss = 1.858838677 and Top-1 accuracy = 0.3360
# Validation-- Top-1 accuracy = 0.3472
# Epoch No. 13--Iteration No. 3550-- Mini-batch loss = 1.819012642 and Top-1 accuracy = 0.3230
# Epoch No. 13--Iteration No. 3600-- Mini-batch loss = 1.860632062 and Top-1 accuracy = 0.3300
# Validation-- Top-1 accuracy = 0.3479
# Epoch No. 13--Iteration No. 3650-- Mini-batch loss = 1.845442414 and Top-1 accuracy = 0.3370
# Epoch No. 14--Iteration No. 3700-- Mini-batch loss = 1.859013915 and Top-1 accuracy = 0.3270
# Validation-- Top-1 accuracy = 0.3478
# Epoch No. 14--Iteration No. 3750-- Mini-batch loss = 1.945108414 and Top-1 accuracy = 0.3220
# Epoch No. 14--Iteration No. 3800-- Mini-batch loss = 1.906602979 and Top-1 accuracy = 0.3380
# Validation-- Top-1 accuracy = 0.3492
# Epoch No. 14--Iteration No. 3850-- Mini-batch loss = 1.884709716 and Top-1 accuracy = 0.3230
# Epoch No. 14--Iteration No. 3900-- Mini-batch loss = 1.886551738 and Top-1 accuracy = 0.3040
# Validation-- Top-1 accuracy = 0.3488
# Epoch No. 15--Iteration No. 3950-- Mini-batch loss = 1.855292201 and Top-1 accuracy = 0.3430
# Epoch No. 15--Iteration No. 4000-- Mini-batch loss = 1.833706260 and Top-1 accuracy = 0.3590
# Validation-- Top-1 accuracy = 0.3491
# Epoch No. 15--Iteration No. 4050-- Mini-batch loss = 1.847282648 and Top-1 accuracy = 0.3350
# Epoch No. 15--Iteration No. 4100-- Mini-batch loss = 1.901593924 and Top-1 accuracy = 0.3500
# Validation-- Top-1 accuracy = 0.3507
# Epoch No. 15--Iteration No. 4150-- Mini-batch loss = 1.756791234 and Top-1 accuracy = 0.3540
# Epoch No. 15--Iteration No. 4200-- Mini-batch loss = 1.813647866 and Top-1 accuracy = 0.3550
# Validation-- Top-1 accuracy = 0.3489
# Epoch No. 16--Iteration No. 4250-- Mini-batch loss = 1.850392938 and Top-1 accuracy = 0.3350
# Epoch No. 16--Iteration No. 4300-- Mini-batch loss = 1.834319472 and Top-1 accuracy = 0.3560
# Validation-- Top-1 accuracy = 0.3507
# Epoch No. 16--Iteration No. 4350-- Mini-batch loss = 1.807981491 and Top-1 accuracy = 0.3400
# Epoch No. 16--Iteration No. 4400-- Mini-batch loss = 1.809137702 and Top-1 accuracy = 0.3570
# Validation-- Top-1 accuracy = 0.3501
# Epoch No. 16--Iteration No. 4450-- Mini-batch loss = 1.865906596 and Top-1 accuracy = 0.3290
# Epoch No. 16--Iteration No. 4500-- Mini-batch loss = 1.794249415 and Top-1 accuracy = 0.3430
# Validation-- Top-1 accuracy = 0.3493
# Epoch No. 17--Iteration No. 4550-- Mini-batch loss = 1.911354303 and Top-1 accuracy = 0.3280
# Epoch No. 17--Iteration No. 4600-- Mini-batch loss = 1.796418905 and Top-1 accuracy = 0.3360
# Validation-- Top-1 accuracy = 0.3498
# Epoch No. 17--Iteration No. 4650-- Mini-batch loss = 1.741041064 and Top-1 accuracy = 0.3770
# Epoch No. 17--Iteration No. 4700-- Mini-batch loss = 1.860219955 and Top-1 accuracy = 0.3410
# Validation-- Top-1 accuracy = 0.3502
# Epoch No. 17--Iteration No. 4750-- Mini-batch loss = 1.775989890 and Top-1 accuracy = 0.3490
# Epoch No. 18--Iteration No. 4800-- Mini-batch loss = 1.714160562 and Top-1 accuracy = 0.3560
# Validation-- Top-1 accuracy = 0.3503
# Epoch No. 18--Iteration No. 4850-- Mini-batch loss = 1.835870266 and Top-1 accuracy = 0.3360
# Epoch No. 18--Iteration No. 4900-- Mini-batch loss = 1.785838246 and Top-1 accuracy = 0.3620
# Validation-- Top-1 accuracy = 0.3502
# Epoch No. 18--Iteration No. 4950-- Mini-batch loss = 1.734156489 and Top-1 accuracy = 0.3610
# Epoch No. 18--Iteration No. 5000-- Mini-batch loss = 1.867990851 and Top-1 accuracy = 0.3360
# Validation-- Top-1 accuracy = 0.3498
# Epoch No. 18--Iteration No. 5050-- Mini-batch loss = 1.698818207 and Top-1 accuracy = 0.3640
# Epoch No. 19--Iteration No. 5100-- Mini-batch loss = 1.811836481 and Top-1 accuracy = 0.3430
# Validation-- Top-1 accuracy = 0.3485
# Epoch No. 19--Iteration No. 5150-- Mini-batch loss = 1.868960738 and Top-1 accuracy = 0.3000
# Epoch No. 19--Iteration No. 5200-- Mini-batch loss = 1.745417714 and Top-1 accuracy = 0.3480
# Validation-- Top-1 accuracy = 0.3527
# Epoch No. 19--Iteration No. 5250-- Mini-batch loss = 1.765455484 and Top-1 accuracy = 0.3590
# Epoch No. 19--Iteration No. 5300-- Mini-batch loss = 1.777656674 and Top-1 accuracy = 0.3490
# Validation-- Top-1 accuracy = 0.3523
# Epoch No. 19--Iteration No. 5350-- Mini-batch loss = 1.816697121 and Top-1 accuracy = 0.3470
# Epoch No. 20--Iteration No. 5400-- Mini-batch loss = 1.753575921 and Top-1 accuracy = 0.3420
# Validation-- Top-1 accuracy = 0.3503
# Epoch No. 20--Iteration No. 5450-- Mini-batch loss = 1.782002687 and Top-1 accuracy = 0.3470
# Epoch No. 20--Iteration No. 5500-- Mini-batch loss = 1.783476591 and Top-1 accuracy = 0.3490
# Validation-- Top-1 accuracy = 0.3503
# Epoch No. 20--Iteration No. 5550-- Mini-batch loss = 1.781596899 and Top-1 accuracy = 0.3420
# Epoch No. 20--Iteration No. 5600-- Mini-batch loss = 1.778356075 and Top-1 accuracy = 0.3390
# Validation-- Top-1 accuracy = 0.3515
# Epoch No. 21--Iteration No. 5650-- Mini-batch loss = 1.953952909 and Top-1 accuracy = 0.3090
# Epoch No. 21--Iteration No. 5700-- Mini-batch loss = 1.826920748 and Top-1 accuracy = 0.3260
# Validation-- Top-1 accuracy = 0.3514
# Epoch No. 21--Iteration No. 5750-- Mini-batch loss = 1.722446680 and Top-1 accuracy = 0.3420
# Epoch No. 21--Iteration No. 5800-- Mini-batch loss = 1.799936891 and Top-1 accuracy = 0.3180
# Validation-- Top-1 accuracy = 0.3532
# Epoch No. 21--Iteration No. 5850-- Mini-batch loss = 1.849478483 and Top-1 accuracy = 0.3330
# Epoch No. 21--Iteration No. 5900-- Mini-batch loss = 1.732741594 and Top-1 accuracy = 0.3540
# Validation-- Top-1 accuracy = 0.3529
# Epoch No. 22--Iteration No. 5950-- Mini-batch loss = 1.811259985 and Top-1 accuracy = 0.3450
# Epoch No. 22--Iteration No. 6000-- Mini-batch loss = 1.816058159 and Top-1 accuracy = 0.3070
# Validation-- Top-1 accuracy = 0.3514
# Epoch No. 22--Iteration No. 6050-- Mini-batch loss = 1.815554738 and Top-1 accuracy = 0.3390
# Epoch No. 22--Iteration No. 6100-- Mini-batch loss = 1.713921309 and Top-1 accuracy = 0.3440
# Validation-- Top-1 accuracy = 0.3534
# Epoch No. 22--Iteration No. 6150-- Mini-batch loss = 1.839343786 and Top-1 accuracy = 0.3320
# Epoch No. 22--Iteration No. 6200-- Mini-batch loss = 1.724497795 and Top-1 accuracy = 0.3590
# Validation-- Top-1 accuracy = 0.3530
# Epoch No. 23--Iteration No. 6250-- Mini-batch loss = 1.721406698 and Top-1 accuracy = 0.3410
# Epoch No. 23--Iteration No. 6300-- Mini-batch loss = 1.853039980 and Top-1 accuracy = 0.3430
# Validation-- Top-1 accuracy = 0.3516
# Epoch No. 23--Iteration No. 6350-- Mini-batch loss = 1.778599620 and Top-1 accuracy = 0.3590
# Epoch No. 23--Iteration No. 6400-- Mini-batch loss = 1.816925764 and Top-1 accuracy = 0.3190
# Validation-- Top-1 accuracy = 0.3513
# Epoch No. 23--Iteration No. 6450-- Mini-batch loss = 1.800217628 and Top-1 accuracy = 0.3220
# Epoch No. 24--Iteration No. 6500-- Mini-batch loss = 1.832632661 and Top-1 accuracy = 0.3120
# Validation-- Top-1 accuracy = 0.3534
# Epoch No. 24--Iteration No. 6550-- Mini-batch loss = 1.774520516 and Top-1 accuracy = 0.3580
# Epoch No. 24--Iteration No. 6600-- Mini-batch loss = 1.831777334 and Top-1 accuracy = 0.3150
# Validation-- Top-1 accuracy = 0.3532
# Epoch No. 24--Iteration No. 6650-- Mini-batch loss = 1.759504914 and Top-1 accuracy = 0.3560
# Epoch No. 24--Iteration No. 6700-- Mini-batch loss = 1.811052680 and Top-1 accuracy = 0.3300
# Validation-- Top-1 accuracy = 0.3522
# Epoch No. 24--Iteration No. 6750-- Mini-batch loss = 1.753092766 and Top-1 accuracy = 0.3400
# Epoch No. 25--Iteration No. 6800-- Mini-batch loss = 1.749831438 and Top-1 accuracy = 0.3680
# Validation-- Top-1 accuracy = 0.3513
# Epoch No. 25--Iteration No. 6850-- Mini-batch loss = 1.804648638 and Top-1 accuracy = 0.3310
# Epoch No. 25--Iteration No. 6900-- Mini-batch loss = 1.727210879 and Top-1 accuracy = 0.3610
# Validation-- Top-1 accuracy = 0.3522
# Epoch No. 25--Iteration No. 6950-- Mini-batch loss = 1.763094187 and Top-1 accuracy = 0.3540
# Epoch No. 25--Iteration No. 7000-- Mini-batch loss = 1.793738484 and Top-1 accuracy = 0.3420
# Validation-- Top-1 accuracy = 0.3558
# Epoch No. 25--Iteration No. 7050-- Mini-batch loss = 1.771267653 and Top-1 accuracy = 0.3900
# Epoch No. 26--Iteration No. 7100-- Mini-batch loss = 1.845702291 and Top-1 accuracy = 0.3450
# Validation-- Top-1 accuracy = 0.3540
# Epoch No. 26--Iteration No. 7150-- Mini-batch loss = 1.703284383 and Top-1 accuracy = 0.3740
# Epoch No. 26--Iteration No. 7200-- Mini-batch loss = 1.729513526 and Top-1 accuracy = 0.3510
# Validation-- Top-1 accuracy = 0.3519
# Epoch No. 26--Iteration No. 7250-- Mini-batch loss = 1.744350433 and Top-1 accuracy = 0.3550
# Epoch No. 26--Iteration No. 7300-- Mini-batch loss = 1.807855844 and Top-1 accuracy = 0.3360
# Validation-- Top-1 accuracy = 0.3543
# Epoch No. 27--Iteration No. 7350-- Mini-batch loss = 1.799781799 and Top-1 accuracy = 0.3310
# Epoch No. 27--Iteration No. 7400-- Mini-batch loss = 1.760432839 and Top-1 accuracy = 0.3440
# Validation-- Top-1 accuracy = 0.3532
# Epoch No. 27--Iteration No. 7450-- Mini-batch loss = 1.787612677 and Top-1 accuracy = 0.3390
# Epoch No. 27--Iteration No. 7500-- Mini-batch loss = 1.766073585 and Top-1 accuracy = 0.3320
# Validation-- Top-1 accuracy = 0.3516
# Epoch No. 27--Iteration No. 7550-- Mini-batch loss = 1.733409524 and Top-1 accuracy = 0.3380
# Epoch No. 27--Iteration No. 7600-- Mini-batch loss = 1.698799968 and Top-1 accuracy = 0.3650
# Validation-- Top-1 accuracy = 0.3557
# Epoch No. 28--Iteration No. 7650-- Mini-batch loss = 1.671110392 and Top-1 accuracy = 0.3580
# Epoch No. 28--Iteration No. 7700-- Mini-batch loss = 1.776653171 and Top-1 accuracy = 0.3380
# Validation-- Top-1 accuracy = 0.3538
# Epoch No. 28--Iteration No. 7750-- Mini-batch loss = 1.700971127 and Top-1 accuracy = 0.3350
# Epoch No. 28--Iteration No. 7800-- Mini-batch loss = 1.738116384 and Top-1 accuracy = 0.3520
# Validation-- Top-1 accuracy = 0.3560
# Epoch No. 28--Iteration No. 7850-- Mini-batch loss = 1.725187540 and Top-1 accuracy = 0.3470
# Epoch No. 29--Iteration No. 7900-- Mini-batch loss = 1.741417527 and Top-1 accuracy = 0.3420
# Validation-- Top-1 accuracy = 0.3550
# Epoch No. 29--Iteration No. 7950-- Mini-batch loss = 1.785903692 and Top-1 accuracy = 0.3370
# Epoch No. 29--Iteration No. 8000-- Mini-batch loss = 1.784996510 and Top-1 accuracy = 0.3590
# Validation-- Top-1 accuracy = 0.3537
# Epoch No. 29--Iteration No. 8050-- Mini-batch loss = 1.756768942 and Top-1 accuracy = 0.3490
# Epoch No. 29--Iteration No. 8100-- Mini-batch loss = 1.844225168 and Top-1 accuracy = 0.3320
# Validation-- Top-1 accuracy = 0.3538
# Epoch No. 29--Iteration No. 8150-- Mini-batch loss = 1.743659973 and Top-1 accuracy = 0.3320
# Epoch No. 30--Iteration No. 8200-- Mini-batch loss = 1.700766802 and Top-1 accuracy = 0.3570
# Validation-- Top-1 accuracy = 0.3540
# Epoch No. 30--Iteration No. 8250-- Mini-batch loss = 1.831922650 and Top-1 accuracy = 0.3240
# Epoch No. 30--Iteration No. 8300-- Mini-batch loss = 1.778712273 and Top-1 accuracy = 0.3520
# Validation-- Top-1 accuracy = 0.3556
# Epoch No. 30--Iteration No. 8350-- Mini-batch loss = 1.749155045 and Top-1 accuracy = 0.3670
# Epoch No. 30--Iteration No. 8400-- Mini-batch loss = 1.731806397 and Top-1 accuracy = 0.3390
# Validation-- Top-1 accuracy = 0.3563
# Epoch No. 30--Iteration No. 8450-- Mini-batch loss = 1.746880651 and Top-1 accuracy = 0.3360
# Epoch No. 31--Iteration No. 8500-- Mini-batch loss = 1.810177565 and Top-1 accuracy = 0.3380
# Validation-- Top-1 accuracy = 0.3534
# Epoch No. 31--Iteration No. 8550-- Mini-batch loss = 1.750151157 and Top-1 accuracy = 0.3610
# Epoch No. 31--Iteration No. 8600-- Mini-batch loss = 1.762911677 and Top-1 accuracy = 0.3280
# Validation-- Top-1 accuracy = 0.3543
# Epoch No. 31--Iteration No. 8650-- Mini-batch loss = 1.713567376 and Top-1 accuracy = 0.3580
# Epoch No. 31--Iteration No. 8700-- Mini-batch loss = 1.758220077 and Top-1 accuracy = 0.3530
# Validation-- Top-1 accuracy = 0.3550
# Epoch No. 32--Iteration No. 8750-- Mini-batch loss = 1.688964605 and Top-1 accuracy = 0.3740
# Epoch No. 32--Iteration No. 8800-- Mini-batch loss = 1.722490788 and Top-1 accuracy = 0.3210
# Validation-- Top-1 accuracy = 0.3542
# Epoch No. 32--Iteration No. 8850-- Mini-batch loss = 1.725807428 and Top-1 accuracy = 0.3540
# Epoch No. 32--Iteration No. 8900-- Mini-batch loss = 1.707989693 and Top-1 accuracy = 0.3520
# Validation-- Top-1 accuracy = 0.3553
# Epoch No. 32--Iteration No. 8950-- Mini-batch loss = 1.760713816 and Top-1 accuracy = 0.3480
# Epoch No. 32--Iteration No. 9000-- Mini-batch loss = 1.740296721 and Top-1 accuracy = 0.3430
# Validation-- Top-1 accuracy = 0.3539
# Epoch No. 33--Iteration No. 9050-- Mini-batch loss = 1.658735156 and Top-1 accuracy = 0.3790
# Epoch No. 33--Iteration No. 9100-- Mini-batch loss = 1.686777711 and Top-1 accuracy = 0.3450
# Validation-- Top-1 accuracy = 0.3546
# Epoch No. 33--Iteration No. 9150-- Mini-batch loss = 1.727239251 and Top-1 accuracy = 0.3580
# Epoch No. 33--Iteration No. 9200-- Mini-batch loss = 1.642010331 and Top-1 accuracy = 0.3570
# Validation-- Top-1 accuracy = 0.3542
# Epoch No. 33--Iteration No. 9250-- Mini-batch loss = 1.710243106 and Top-1 accuracy = 0.3750
# Epoch No. 33--Iteration No. 9300-- Mini-batch loss = 1.658293724 and Top-1 accuracy = 0.3770
# Validation-- Top-1 accuracy = 0.3522
# Epoch No. 34--Iteration No. 9350-- Mini-batch loss = 1.736730695 and Top-1 accuracy = 0.3440
# Epoch No. 34--Iteration No. 9400-- Mini-batch loss = 1.722560763 and Top-1 accuracy = 0.3460
# Validation-- Top-1 accuracy = 0.3526
# Epoch No. 34--Iteration No. 9450-- Mini-batch loss = 1.719942808 and Top-1 accuracy = 0.3520
# Epoch No. 34--Iteration No. 9500-- Mini-batch loss = 1.720714688 and Top-1 accuracy = 0.3430
# Validation-- Top-1 accuracy = 0.3542
# Epoch No. 34--Iteration No. 9550-- Mini-batch loss = 1.772442341 and Top-1 accuracy = 0.3530
# Epoch No. 35--Iteration No. 9600-- Mini-batch loss = 1.731353521 and Top-1 accuracy = 0.3390
# Validation-- Top-1 accuracy = 0.3554
# Epoch No. 35--Iteration No. 9650-- Mini-batch loss = 1.696955681 and Top-1 accuracy = 0.3550
# Epoch No. 35--Iteration No. 9700-- Mini-batch loss = 1.741127729 and Top-1 accuracy = 0.3390
# Validation-- Top-1 accuracy = 0.3572
# Epoch No. 35--Iteration No. 9750-- Mini-batch loss = 1.811798811 and Top-1 accuracy = 0.3380
# Epoch No. 35--Iteration No. 9800-- Mini-batch loss = 1.680996060 and Top-1 accuracy = 0.3710
# Validation-- Top-1 accuracy = 0.3546
# Epoch No. 35--Iteration No. 9850-- Mini-batch loss = 1.699759960 and Top-1 accuracy = 0.3480
# Epoch No. 36--Iteration No. 9900-- Mini-batch loss = 1.682952762 and Top-1 accuracy = 0.3510
# Validation-- Top-1 accuracy = 0.3522
# Epoch No. 36--Iteration No. 9950-- Mini-batch loss = 1.812979460 and Top-1 accuracy = 0.3540
# Epoch No. 36--Iteration No. 10000-- Mini-batch loss = 1.642732263 and Top-1 accuracy = 0.3590
# Validation-- Top-1 accuracy = 0.3572
# Epoch No. 36--Iteration No. 10050-- Mini-batch loss = 1.627980709 and Top-1 accuracy = 0.3740
# Epoch No. 36--Iteration No. 10100-- Mini-batch loss = 1.773431659 and Top-1 accuracy = 0.3350
# Validation-- Top-1 accuracy = 0.3573
# Epoch No. 36--Iteration No. 10150-- Mini-batch loss = 1.783582449 and Top-1 accuracy = 0.3320
# Epoch No. 37--Iteration No. 10200-- Mini-batch loss = 1.719726920 and Top-1 accuracy = 0.3430
# Validation-- Top-1 accuracy = 0.3536
# Epoch No. 37--Iteration No. 10250-- Mini-batch loss = 1.758469701 and Top-1 accuracy = 0.3260
# Epoch No. 37--Iteration No. 10300-- Mini-batch loss = 1.701528311 and Top-1 accuracy = 0.3430
# Validation-- Top-1 accuracy = 0.3552
# Epoch No. 37--Iteration No. 10350-- Mini-batch loss = 1.773087144 and Top-1 accuracy = 0.3400
# Epoch No. 37--Iteration No. 10400-- Mini-batch loss = 1.787447810 and Top-1 accuracy = 0.3240
# Validation-- Top-1 accuracy = 0.3561
# Epoch No. 38--Iteration No. 10450-- Mini-batch loss = 1.729127526 and Top-1 accuracy = 0.3530
# Epoch No. 38--Iteration No. 10500-- Mini-batch loss = 1.728191614 and Top-1 accuracy = 0.3540
# Validation-- Top-1 accuracy = 0.3548
# Epoch No. 38--Iteration No. 10550-- Mini-batch loss = 1.711733818 and Top-1 accuracy = 0.3380
# Epoch No. 38--Iteration No. 10600-- Mini-batch loss = 1.691761374 and Top-1 accuracy = 0.3320
# Validation-- Top-1 accuracy = 0.3534
# Epoch No. 38--Iteration No. 10650-- Mini-batch loss = 1.725644946 and Top-1 accuracy = 0.3430
# Epoch No. 38--Iteration No. 10700-- Mini-batch loss = 1.690250635 and Top-1 accuracy = 0.3460
# Validation-- Top-1 accuracy = 0.3567
# Epoch No. 39--Iteration No. 10750-- Mini-batch loss = 1.735731483 and Top-1 accuracy = 0.3270
# Epoch No. 39--Iteration No. 10800-- Mini-batch loss = 1.825042009 and Top-1 accuracy = 0.3270
# Validation-- Top-1 accuracy = 0.3547
# Epoch No. 39--Iteration No. 10850-- Mini-batch loss = 1.769697666 and Top-1 accuracy = 0.3520
# Epoch No. 39--Iteration No. 10900-- Mini-batch loss = 1.740582466 and Top-1 accuracy = 0.3340
# Validation-- Top-1 accuracy = 0.3568
# Epoch No. 39--Iteration No. 10950-- Mini-batch loss = 1.740224600 and Top-1 accuracy = 0.3150
# Epoch No. 40--Iteration No. 11000-- Mini-batch loss = 1.730306983 and Top-1 accuracy = 0.3460
# Validation-- Top-1 accuracy = 0.3560
# Epoch No. 40--Iteration No. 11050-- Mini-batch loss = 1.683610916 and Top-1 accuracy = 0.3640
# Epoch No. 40--Iteration No. 11100-- Mini-batch loss = 1.734900832 and Top-1 accuracy = 0.3240
# Validation-- Top-1 accuracy = 0.3551
# Epoch No. 40--Iteration No. 11150-- Mini-batch loss = 1.776920080 and Top-1 accuracy = 0.3560
# Epoch No. 40--Iteration No. 11200-- Mini-batch loss = 1.615892410 and Top-1 accuracy = 0.3670
# Validation-- Top-1 accuracy = 0.3550
# Epoch No. 40--Iteration No. 11250-- Mini-batch loss = 1.704851508 and Top-1 accuracy = 0.3560
# Epoch No. 41--Iteration No. 11300-- Mini-batch loss = 1.733918309 and Top-1 accuracy = 0.3400
# Validation-- Top-1 accuracy = 0.3544
# Epoch No. 41--Iteration No. 11350-- Mini-batch loss = 1.716400146 and Top-1 accuracy = 0.3500
# Epoch No. 41--Iteration No. 11400-- Mini-batch loss = 1.674310327 and Top-1 accuracy = 0.3530
# Validation-- Top-1 accuracy = 0.3569
# Epoch No. 41--Iteration No. 11450-- Mini-batch loss = 1.678038120 and Top-1 accuracy = 0.3700
# Epoch No. 41--Iteration No. 11500-- Mini-batch loss = 1.756713867 and Top-1 accuracy = 0.3320
# Validation-- Top-1 accuracy = 0.3554
# Epoch No. 41--Iteration No. 11550-- Mini-batch loss = 1.680816650 and Top-1 accuracy = 0.3520
# Epoch No. 42--Iteration No. 11600-- Mini-batch loss = 1.802883625 and Top-1 accuracy = 0.3310
# Validation-- Top-1 accuracy = 0.3529
# Epoch No. 42--Iteration No. 11650-- Mini-batch loss = 1.688582063 and Top-1 accuracy = 0.3400
# Epoch No. 42--Iteration No. 11700-- Mini-batch loss = 1.655079842 and Top-1 accuracy = 0.3710
# Validation-- Top-1 accuracy = 0.3557
# Epoch No. 42--Iteration No. 11750-- Mini-batch loss = 1.750019312 and Top-1 accuracy = 0.3490
# Epoch No. 42--Iteration No. 11800-- Mini-batch loss = 1.680063725 and Top-1 accuracy = 0.3670
# Validation-- Top-1 accuracy = 0.3533
# Epoch No. 43--Iteration No. 11850-- Mini-batch loss = 1.624160886 and Top-1 accuracy = 0.3690
# Epoch No. 43--Iteration No. 11900-- Mini-batch loss = 1.710320115 and Top-1 accuracy = 0.3320
# Validation-- Top-1 accuracy = 0.3540
# Epoch No. 43--Iteration No. 11950-- Mini-batch loss = 1.704923630 and Top-1 accuracy = 0.3670
# Epoch No. 43--Iteration No. 12000-- Mini-batch loss = 1.629378676 and Top-1 accuracy = 0.3660
# Validation-- Top-1 accuracy = 0.3574
# Epoch No. 43--Iteration No. 12050-- Mini-batch loss = 1.749012351 and Top-1 accuracy = 0.3420
# Epoch No. 43--Iteration No. 12100-- Mini-batch loss = 1.616045713 and Top-1 accuracy = 0.3680
# Validation-- Top-1 accuracy = 0.3551
# Epoch No. 44--Iteration No. 12150-- Mini-batch loss = 1.721925020 and Top-1 accuracy = 0.3540
# Epoch No. 44--Iteration No. 12200-- Mini-batch loss = 1.769116402 and Top-1 accuracy = 0.3110
# Validation-- Top-1 accuracy = 0.3553
# Epoch No. 44--Iteration No. 12250-- Mini-batch loss = 1.647395492 and Top-1 accuracy = 0.3420
# Epoch No. 44--Iteration No. 12300-- Mini-batch loss = 1.681081891 and Top-1 accuracy = 0.3760
# Validation-- Top-1 accuracy = 0.3535
# Epoch No. 44--Iteration No. 12350-- Mini-batch loss = 1.707162738 and Top-1 accuracy = 0.3610
# Epoch No. 44--Iteration No. 12400-- Mini-batch loss = 1.727198243 and Top-1 accuracy = 0.3550
# Validation-- Top-1 accuracy = 0.3571
# Epoch No. 45--Iteration No. 12450-- Mini-batch loss = 1.684779048 and Top-1 accuracy = 0.3570
# Epoch No. 45--Iteration No. 12500-- Mini-batch loss = 1.680591822 and Top-1 accuracy = 0.3510
# Validation-- Top-1 accuracy = 0.3550
# Epoch No. 45--Iteration No. 12550-- Mini-batch loss = 1.705229640 and Top-1 accuracy = 0.3540
# Epoch No. 45--Iteration No. 12600-- Mini-batch loss = 1.718567371 and Top-1 accuracy = 0.3530
# Validation-- Top-1 accuracy = 0.3550
# Epoch No. 45--Iteration No. 12650-- Mini-batch loss = 1.705993891 and Top-1 accuracy = 0.3380
# Epoch No. 46--Iteration No. 12700-- Mini-batch loss = 1.862491250 and Top-1 accuracy = 0.3180
# Validation-- Top-1 accuracy = 0.3572
# Epoch No. 46--Iteration No. 12750-- Mini-batch loss = 1.754263639 and Top-1 accuracy = 0.3210
# Epoch No. 46--Iteration No. 12800-- Mini-batch loss = 1.647845268 and Top-1 accuracy = 0.3430
# Validation-- Top-1 accuracy = 0.3536
# Epoch No. 46--Iteration No. 12850-- Mini-batch loss = 1.722890019 and Top-1 accuracy = 0.3210
# Epoch No. 46--Iteration No. 12900-- Mini-batch loss = 1.770783067 and Top-1 accuracy = 0.3310
# Validation-- Top-1 accuracy = 0.3566
# Epoch No. 46--Iteration No. 12950-- Mini-batch loss = 1.660171270 and Top-1 accuracy = 0.3520
# Epoch No. 47--Iteration No. 13000-- Mini-batch loss = 1.745242953 and Top-1 accuracy = 0.3520
# Validation-- Top-1 accuracy = 0.3541
# Epoch No. 47--Iteration No. 13050-- Mini-batch loss = 1.752177119 and Top-1 accuracy = 0.3150
# Epoch No. 47--Iteration No. 13100-- Mini-batch loss = 1.755316019 and Top-1 accuracy = 0.3300
# Validation-- Top-1 accuracy = 0.3558
# Epoch No. 47--Iteration No. 13150-- Mini-batch loss = 1.646510959 and Top-1 accuracy = 0.3490
# Epoch No. 47--Iteration No. 13200-- Mini-batch loss = 1.764290571 and Top-1 accuracy = 0.3290
# Validation-- Top-1 accuracy = 0.3579
# Epoch No. 47--Iteration No. 13250-- Mini-batch loss = 1.644977927 and Top-1 accuracy = 0.3670
# Epoch No. 48--Iteration No. 13300-- Mini-batch loss = 1.659094095 and Top-1 accuracy = 0.3450
# Validation-- Top-1 accuracy = 0.3554
# Epoch No. 48--Iteration No. 13350-- Mini-batch loss = 1.797481060 and Top-1 accuracy = 0.3480
# Epoch No. 48--Iteration No. 13400-- Mini-batch loss = 1.702718735 and Top-1 accuracy = 0.3570
# Validation-- Top-1 accuracy = 0.3558
# Epoch No. 48--Iteration No. 13450-- Mini-batch loss = 1.742083788 and Top-1 accuracy = 0.3320
# Epoch No. 48--Iteration No. 13500-- Mini-batch loss = 1.733777285 and Top-1 accuracy = 0.3230
# Validation-- Top-1 accuracy = 0.3568
# Epoch No. 49--Iteration No. 13550-- Mini-batch loss = 1.765634775 and Top-1 accuracy = 0.3210
# Epoch No. 49--Iteration No. 13600-- Mini-batch loss = 1.713332057 and Top-1 accuracy = 0.3570
# Validation-- Top-1 accuracy = 0.3535
# Epoch No. 49--Iteration No. 13650-- Mini-batch loss = 1.753112912 and Top-1 accuracy = 0.3200
# Epoch No. 49--Iteration No. 13700-- Mini-batch loss = 1.714873075 and Top-1 accuracy = 0.3540
# Validation-- Top-1 accuracy = 0.3553
# Epoch No. 49--Iteration No. 13750-- Mini-batch loss = 1.736699581 and Top-1 accuracy = 0.3330
# Epoch No. 49--Iteration No. 13800-- Mini-batch loss = 1.701905847 and Top-1 accuracy = 0.3370
# Validation-- Top-1 accuracy = 0.3565
# Epoch No. 50--Iteration No. 13850-- Mini-batch loss = 1.670755625 and Top-1 accuracy = 0.3570
# Epoch No. 50--Iteration No. 13900-- Mini-batch loss = 1.746797085 and Top-1 accuracy = 0.3310
# Validation-- Top-1 accuracy = 0.3569
# Epoch No. 50--Iteration No. 13950-- Mini-batch loss = 1.663989902 and Top-1 accuracy = 0.3530
# Epoch No. 50--Iteration No. 14000-- Mini-batch loss = 1.712988615 and Top-1 accuracy = 0.3660
# Validation-- Top-1 accuracy = 0.3573
# Epoch No. 50--Iteration No. 14050-- Mini-batch loss = 1.734046459 and Top-1 accuracy = 0.3420
# Epoch No. 50--Iteration No. 14100-- Mini-batch loss = 1.726613760 and Top-1 accuracy = 0.4000
# Validation-- Top-1 accuracy = 0.3578
# Training lasted 26546738.757 minutes
# ------------------------ Training Done ------------------------
# <Figure size 640x480 with 1 Axes>
